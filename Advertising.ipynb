# %% [markdown]
# # Data Analysis on Advertising Based on rating on TV,Radio,Newspaper,Sales

# %%
# import the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv("Advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#get the sum of nullvalues
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# # Visulization

# %%
sns.distplot(df['Sales'])
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
#bar graph between TV and Sales
import matplotlib.pyplot as plt
plt.bar(df['TV'].head(),df['Sales'].head())
plt.xlabel('TV')
plt.ylabel('Sales')
plt.title('TV vs Sales')
plt.show()

# %%
# histograph between Radio vs Sales
plt.bar(df['Radio'].head(),df['Sales'].head())
plt.xlabel('Radio')
plt.ylabel('Sales')
plt.title('Radio vs Sales')
plt.show()

# %%
#histograph between NewsPaper vs Sales
plt.bar(df['Newspaper'].tail(),df['Sales'].tail())
plt.title('NewsPaper vs Sales')
plt.xlabel('Newspaper')
plt.ylabel('sales')
plt.show()

# %%
# plot between Tv vs Sales
sns.barplot(df['Sales'].head(),df['TV'].head())
plt.show()

# %%
sns.barplot(df['Sales'].head(),df['Radio'].head())
plt.show()

# %%
sns.barplot(df['Sales'].head(),df['Newspaper'].head())
plt.show()

# %%
sns.boxplot(x='Sales',y='TV',data=df)
plt.show()

# %%
sns.boxplot(df['TV'])
# Out:
# <AxesSubplot:xlabel='TV'>

# %%
sns.boxplot(df['Radio'])
plt.show()

# %%
sns.boxplot(df['Newspaper'])
# Out:
# <AxesSubplot:xlabel='Newspaper'>

# %%
# pie chart 
df[['TV','Radio','Newspaper']].sum().plot(kind='pie')
plt.show()

# %%
# correlation
df.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
# heatmap
co=df.corr()
fig,ax=plt.subplots(figsize=(5,5))
sns.heatmap(co,annot=True,ax=ax)
plt.show()

# %%
# scatterplot 
sns.scatterplot(x='Sales',y='TV',data=df)
plt.show()

# %%
sns.scatterplot(x='Sales',y='Newspaper',data=df)
plt.show()

# %%
sns.scatterplot(x='Sales',y='Newspaper',data=df)
plt.show()

# %%
df['TV']
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV, Length: 200, dtype: float64

# %% [markdown]
# # Learning Algorithm

# %%
from sklearn.linear_model import LinearRegression
new=['TV','Radio','Newspaper']

X=df[new]
Y=df['Sales']

# %%
model=LinearRegression()
model=model.fit(X,Y)

# %%
model.intercept_
# Out:
# 2.9388893694594085

# %%
model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
Y_pred=model.predict(X)
Y_pred
# Out:
# array([20.52397441, 12.33785482, 12.30767078, 17.59782951, 13.18867186,
#        12.47834763, 11.72975995, 12.12295317,  3.72734086, 12.55084872,
#         7.0322992 , 17.28512918, 10.57712073,  8.82630048, 18.43436638,
#        20.81929952, 12.82365674, 23.22495716,  9.95168206, 14.16607293,
#        18.10076728, 14.7405382 ,  6.4891503 , 16.5459329 ,  8.14651887,
#        15.6100386 , 14.98951429, 17.05167344, 19.41053803,  9.14402389,
#        21.6339338 , 11.3460929 ,  7.63888314, 18.86426829,  7.57483051,
#        17.00682618, 23.40590052, 15.62347779,  9.90868103, 20.44761039,
#        16.37766467, 17.2959832 , 21.59580326, 13.96385684,  8.88787996,
#        15.16152314,  8.87338673, 21.7226299 , 16.26362018,  8.1681656 ,
#        12.63121132,  9.33981296, 20.66297563, 19.94469957, 20.37443008,
#        21.2926106 ,  8.52771254, 12.77458802, 21.89805198, 18.13348698,
#         5.74215558, 22.89067208, 16.78426073, 13.21069202, 16.97773556,
# ...

# %%
# score
model.score(X,Y)
# Out:
# 0.8972106381789522

# %%
# give the input and predict the sales
new_x=[[600,300,60]]
model.predict(new_x)
# Out:
# array([86.89443214])

# %%
# predict the score
new=[[230.1,37.8,69.2]]
model.predict(new)
# Out:
# array([20.52397441])
